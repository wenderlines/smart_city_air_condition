# %% [markdown]
# <h3>Paxton Wenderline Jones
#     <br>
# Course: BIT-6
#     <br>
# ID: 026-720
#     <br>
# module: System audit</h3>

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
# Air Quality datasets 
# https://aqs.epa.gov/aqsweb/airdata/download_files.html#Raw
# !wget https://aqs.epa.gov/aqsweb/airdata/hourly_42602_2017.zip
# !unzip hourly_42602_2017.zip
# Out:
# --2020-12-21 12:58:26--  https://aqs.epa.gov/aqsweb/airdata/hourly_42602_2017.zip
# Resolving aqs.epa.gov (aqs.epa.gov)... 134.67.21.26
# Connecting to aqs.epa.gov (aqs.epa.gov)|134.67.21.26|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 28265816 (27M) [application/zip]
# Saving to: ‘hourly_42602_2017.zip’
#
# hourly_42602_2017.z 100%[===================>]  26.96M  2.87MB/s    in 9.5s
#
# 2020-12-21 12:58:36 (2.84 MB/s) - ‘hourly_42602_2017.zip’ saved [28265816/28265816]
#
# Archive:  hourly_42602_2017.zip
#   inflating: hourly_42602_2017.csv

# %%
# !ls
# Out:
# apt.txt		 hourly_42602_2017.csv	Index.ipynb
# environment.yml  hourly_42602_2017.zip

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
# Load dataset 
aq_data = pd.read_csv('./hourly_42602_2017.csv')
# aq_data = pd.read_csv('/Users/kkbankol@us.ibm.com/Downloads/hourly_42602_2017.csv')
# Out:
# /srv/conda/envs/notebook/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (17) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# View first 5 rows
aq_data.head()
# Out:
#    State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 0           1           73        23           42602    1  33.553056
# 1           1           73        23           42602    1  33.553056
# 2           1           73        23           42602    1  33.553056
# 3           1           73        23           42602    1  33.553056
# 4           1           73        23           42602    1  33.553056
#
#    Longitude  Datum          Parameter Name  Date Local  ...  \
# 0    -86.815  WGS84  Nitrogen dioxide (NO2)  2017-01-01  ...
# 1    -86.815  WGS84  Nitrogen dioxide (NO2)  2017-01-01  ...
# 2    -86.815  WGS84  Nitrogen dioxide (NO2)  2017-01-01  ...
# 3    -86.815  WGS84  Nitrogen dioxide (NO2)  2017-01-01  ...
# 4    -86.815  WGS84  Nitrogen dioxide (NO2)  2017-01-01  ...
#
#     Units of Measure  MDL Uncertainty  Qualifier Method Type  Method Code  \
# 0  Parts per billion  0.1         NaN        NaN         FEM          200
# 1  Parts per billion  0.1         NaN        NaN         FEM          200
# 2  Parts per billion  0.1         NaN        NaN         FEM          200
# 3  Parts per billion  0.1         NaN        NaN         FEM          200
# 4  Parts per billion  0.1         NaN        NaN         FEM          200
#
#                                          Method Name State Name County Name  \
# 0  Teledyne-API Model 200EUP or T200UP - Photolyt...    Alabama   Jefferson
# 1  Teledyne-API Model 200EUP or T200UP - Photolyt...    Alabama   Jefferson
# 2  Teledyne-API Model 200EUP or T200UP - Photolyt...    Alabama   Jefferson
# 3  Teledyne-API Model 200EUP or T200UP - Photolyt...    Alabama   Jefferson
# 4  Teledyne-API Model 200EUP or T200UP - Photolyt...    Alabama   Jefferson
#
#    Date of Last Change
# 0           2017-04-19
# 1           2017-04-19
# 2           2017-04-19
# 3           2017-04-19
# 4           2017-04-19
#
# [5 rows x 24 columns]

# %%
# View titles of all columns
aq_data.columns
# Out:
# Index(['State Code', 'County Code', 'Site Num', 'Parameter Code', 'POC',
#        'Latitude', 'Longitude', 'Datum', 'Parameter Name', 'Date Local',
#        'Time Local', 'Date GMT', 'Time GMT', 'Sample Measurement',
#        'Units of Measure', 'MDL', 'Uncertainty', 'Qualifier', 'Method Type',
#        'Method Code', 'Method Name', 'State Name', 'County Name',
#        'Date of Last Change'],
#       dtype='object')

# %%
aq_data['Sample Measurement'].describe()
# Out:
# count    3.561691e+06
# mean     8.242666e+00
# std      9.165297e+00
# min     -5.000000e+00
# 25%      2.000000e+00
# 50%      5.000000e+00
# 75%      1.120000e+01
# max      1.296000e+02
# Name: Sample Measurement, dtype: float64

# %%
# print list of all unique monitoring site numbers
aq_data['Site Num'].unique()
# Out:
# array([  23, 2059,   34,   19, 3002, 4011, 4019, 4020, 9997, 1011, 1028,
#           5,    7,    9,   11,   12,   13, 2005,    8,    2, 1002, 1004,
#        2007,  242, 2016, 4001, 5001, 1005, 1003,   14, 2012, 6001,   16,
#         113, 1103, 1201, 1302, 1602, 1701, 4006, 4008, 5005, 6012, 9033,
#           4,    1,    3,    6, 1016, 8001, 8005, 9001,   10,   15,   26,
#          27,  306, 1234, 2002, 9004, 1006, 1008, 1014, 1017, 1022, 3005,
#        4002, 8002, 1001, 1013, 1018, 1021, 1025, 2004, 2011, 4003, 3001,
#        7004,   28, 7001, 7003, 9003,   25,   41,   43,   50,   51,   35,
#          32,  108, 1065,   21,   18,   56,   63,   76, 3103,   22,   78,
#          87,   30,   17,   67,   75, 1024, 1100,   29,   40, 2006, 4005,
#        3003,   42,   44,   93,   94,   95, 1010,   20,  423,  480,  962,
#          85,   86,  760,  761,  762,  540,  561, 1501, 1502, 1233,  110,
#         133,  124,  125,   45,   60,   73,   37,   38,   48,  101,   65,
#          33,   97, 9021, 1127,   80, 1376,  100, 4000, 5200,   46,   59,
#        1069,   69, 1067, 1044,   55, 1034,   24,   47,  416, 1015, 1035,
#        1039, 1050, 1052, 1066, 1037, 1051, 1053, 3009, 3011, 1068, 7011,
#        3006, 3013, 2003, 7022,   31,  123,  456,  892,   99,  232, 2601,
#         700,  200,  300])

# %%
# get number of aq sites in a single state, "California"
aq_data.loc[aq_data['State Name'] == "California"]['Site Num'].unique().shape
# Out:
# (66,)

# %%
# show data associated 
los_angeles_aq = aq_data.loc[ \
                     (aq_data['Longitude'] > -118.455937) & \
                     (aq_data['Longitude'] < -117.842111) & \
                     (aq_data['Latitude'] > 33.764836) & \
                     (aq_data['Latitude'] < 34.173729) ]
los_angeles_aq
# Out:
#         State Code  County Code  Site Num  Parameter Code  POC  Latitude  \
# 308750           6           37         2           42602    2  34.13650
# 308751           6           37         2           42602    2  34.13650
# 308752           6           37         2           42602    2  34.13650
# 308753           6           37         2           42602    2  34.13650
# 308754           6           37         2           42602    2  34.13650
# ...            ...          ...       ...             ...  ...       ...
# 494138           6           59      5001           42602    2  33.92513
# 494139           6           59      5001           42602    2  33.92513
# 494140           6           59      5001           42602    2  33.92513
# 494141           6           59      5001           42602    2  33.92513
# 494142           6           59      5001           42602    2  33.92513
#
#         Longitude  Datum          Parameter Name  Date Local  ...  \
# 308750 -117.92391  WGS84  Nitrogen dioxide (NO2)  2017-01-01  ...
# 308751 -117.92391  WGS84  Nitrogen dioxide (NO2)  2017-01-01  ...
# 308752 -117.92391  WGS84  Nitrogen dioxide (NO2)  2017-01-01  ...
# 308753 -117.92391  WGS84  Nitrogen dioxide (NO2)  2017-01-01  ...
# 308754 -117.92391  WGS84  Nitrogen dioxide (NO2)  2017-01-01  ...
# ...           ...    ...                     ...         ...  ...
# 494138 -117.95264  WGS84  Nitrogen dioxide (NO2)  2017-12-30  ...
# 494139 -117.95264  WGS84  Nitrogen dioxide (NO2)  2017-12-30  ...
# 494140 -117.95264  WGS84  Nitrogen dioxide (NO2)  2017-12-30  ...
# 494141 -117.95264  WGS84  Nitrogen dioxide (NO2)  2017-12-30  ...
# 494142 -117.95264  WGS84  Nitrogen dioxide (NO2)  2017-12-31  ...
#
#          Units of Measure  MDL Uncertainty  Qualifier Method Type  \
# 308750  Parts per billion  1.0         NaN        NaN         FRM
# 308751  Parts per billion  1.0         NaN        NaN         FRM
# 308752  Parts per billion  1.0         NaN        NaN         FRM
# 308753  Parts per billion  1.0         NaN        NaN         FRM
# 308754  Parts per billion  1.0         NaN        NaN         FRM
# ...                   ...  ...         ...        ...         ...
# 494138  Parts per billion  1.0         NaN        NaN         FRM
# 494139  Parts per billion  1.0         NaN        NaN         FRM
# 494140  Parts per billion  1.0         NaN        NaN         FRM
# 494141  Parts per billion  1.0         NaN        NaN         FRM
# 494142  Parts per billion  1.0         NaN        NaN         FRM
#
#         Method Code                       Method Name  State Name  \
# 308750           74  INSTRUMENTAL - CHEMILUMINESCENCE  California
# 308751           74  INSTRUMENTAL - CHEMILUMINESCENCE  California
# 308752           74  INSTRUMENTAL - CHEMILUMINESCENCE  California
# 308753           74  INSTRUMENTAL - CHEMILUMINESCENCE  California
# 308754           74  INSTRUMENTAL - CHEMILUMINESCENCE  California
# ...             ...                               ...         ...
# 494138           74  INSTRUMENTAL - CHEMILUMINESCENCE  California
# 494139           74  INSTRUMENTAL - CHEMILUMINESCENCE  California
# 494140           74  INSTRUMENTAL - CHEMILUMINESCENCE  California
# 494141           74  INSTRUMENTAL - CHEMILUMINESCENCE  California
# 494142           74  INSTRUMENTAL - CHEMILUMINESCENCE  California
#
#         County Name  Date of Last Change
# 308750  Los Angeles           2017-06-27
# 308751  Los Angeles           2017-06-27
# 308752  Los Angeles           2017-06-27
# 308753  Los Angeles           2017-06-27
# 308754  Los Angeles           2017-06-27
# ...             ...                  ...
# 494138       Orange           2018-02-20
# 494139       Orange           2018-02-20
# 494140       Orange           2018-02-20
# 494141       Orange           2018-02-20
# 494142       Orange           2018-02-20
#
# [101620 rows x 24 columns]

# %%
import datetime as dt

# foo = ((los_angeles_aq['Date Local'].astype(str) + " " + los_angeles_aq['Time Local']) - dt.datetime(1970,1,1)).dt.total_seconds()
# los_angeles_aq['Timestamp'] = (pd.to_datetime((los_angeles_aq['Date Local'].astype(str) + "-" + los_angeles_aq['Time Local']))).dt.total_seconds()
los_angeles_aq['Timestamp'] = (pd.to_datetime((los_angeles_aq['Date Local'].astype(str) + "-" + los_angeles_aq['Time Local'])) - dt.datetime(1970,1,1)).dt.total_seconds()
# .date.astype('int64')

# los_angeles_aq['Date']
# Out:
# /srv/conda/envs/notebook/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
los_angeles_aq['Timestamp']
# import time, datetime
# s = los_angeles_aq.iloc[0]['Date Local'] + '-' + los_angeles_aq.iloc[0]['Time Local']
# int(time.mktime(datetime.datetime.strptime(s, "%Y-%d-%m-%H:%M").timetuple()))
# los_angeles_aq['Timestamp'] = pd.to_datetime([los_angeles_aq['Date Local'] + los_angeles_aq['Time Local'] ])
# los_angeles_aq.iloc[0]['Date Local'] + los_angeles_aq.iloc[0]['Time Local']
# Out:
# 308750    1.483229e+09
# 308751    1.483232e+09
# 308752    1.483236e+09
# 308753    1.483240e+09
# 308754    1.483243e+09
#               ...
# 494138    1.514664e+09
# 494139    1.514668e+09
# 494140    1.514671e+09
# 494141    1.514675e+09
# 494142    1.514678e+09
# Name: Timestamp, Length: 101620, dtype: float64

# %%
plt.ylabel('Air Quality Level')
plt.xlabel('Timestamp')
plt.legend( los_angeles_aq['Site Num'].unique().tolist(), loc='upper left')
# plt.legend( los_angeles_aq['Site Num'].unique().tolist() )
# colors = [plt.cm.spectral(i) for i in np.linspace(0, 1, los_angeles_aq['Site Num'].unique().shape[0])]
# ax.set_prop_cycle('color', colors)
los_angeles_aq_trimmed = los_angeles_aq
for site in los_angeles_aq['Site Num'].unique():
    plt.plot( los_angeles_aq_trimmed.loc[los_angeles_aq_trimmed['Site Num'] == site]['Timestamp'], los_angeles_aq_trimmed.loc[los_angeles_aq_trimmed['Site Num'] == site]['Sample Measurement'])

# %%
# Print aq changes throughout the year, and create a seperate chart for each air quality monitoring site
ncols = 3
nrows = 4 #los_angeles_aq['Site Num'].unique().shape[0]
plt.subplots(nrows, ncols, figsize=(15,15))
idx = 1
data_summary = los_angeles_aq['Sample Measurement'].describe()
for site in los_angeles_aq['Site Num'].unique():
    plt.ylim(0, data_summary['max'] * 1.25)
    plt.subplot(nrows, ncols, idx)
    plt.plot( los_angeles_aq.loc[los_angeles_aq['Site Num'] == site]['Timestamp'], los_angeles_aq.loc[los_angeles_aq['Site Num'] == site]['Sample Measurement'])
    plt.title("site " + str(site))
    idx = idx + 1

# %%
# extract day of week
import datetime
los_angeles_aq['Weekday'] = pd.to_datetime(los_angeles_aq['Date Local']).dt.day_name()
# Out:
# /srv/conda/envs/notebook/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Print aq changes throughout the day from 0:00 - 24:00. Break into seperate plots by weekday
nrows = 4
ncols = 2
plt.subplots(nrows, ncols, figsize=(15,15))
weekdays = [ 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday' ]
idx = 1
values_by_weekday = {}
for day in weekdays:
    plt.subplot(nrows, ncols, idx)
    # for loop 0:00 - 24:00
    # sum measurements where weekday == and time ==
    times = []
    for hour in range(0, 23):
        if hour <= 9:
          time = "0" + str(hour) + ":00"
        else:
          time = str(hour) + ":00"
        # select subset matching given weekday and hour
        subset = los_angeles_aq.loc[ (los_angeles_aq['Weekday'] == day) & (los_angeles_aq['Time Local'] == time) ]['Sample Measurement']
        #         print(subset.mean())
        times.append(subset.sum())
    values_by_weekday[day] = times
    plt.plot( times )
    plt.title(day)
    idx = idx + 1

# %% [markdown]
# <h4> 2. Develop the problem statements of the project as markdown. (2 marks)
# </h4>
#  capturing Data using Datamachine learning tools to computerise the air condition of a city"

# %% [markdown]
# <h4>3. State the general objective of the project as markdown. (2 marks)</h4>
#
# <p>To Avoid Air pollution </p>

# %% [markdown]
# <h4>4. Outline any three specific objectives of the project as markdown
# </h4>
#
# 1. capturing of data and data analysis
# 2. informing people the dangers of air pollution
# 3. Avoid wheather catastrophy

# %% [markdown]
# <h4>5. State the possible Research questions for this project as markdown. (2 marks)</h4>
#
# <p>"Assess the impact of technology on climate change in california "</p>

# %% [markdown]
# <h4>6. As an Information System Auditor, outline the observations/research findings demonstrated in the graphs from the data set as markdown. (2 marks)</h4>
#
# <b>Research findings demostrated in the graph</b>
#
# Annual,monthly,weekly as well as daily data traffic record about wheather in certain cities
#
#  the air quality from los_angeles_aq has been monitored annualy, weekly data traffic basis playing in the range of (0 to 23)

# %% [markdown]
# <h4>7. What new ideas were proposed in this project? (Hint. Answers as markdown) (2 marks)</h4>
#
#
#
# <p>using machine learning tools and web based technology to come up with means of protecting and maintaining people's lives.

# %% [markdown]
# <h4>8. Develop the conclusion of the project as markdown. (2 marks)</h4>
#
# <p>
#
# Predicting the air quality is a complex task due to the dynamic nature, volatility, and high variability in space and time of pollutants and particulates. At the same time, being able to model, predict, and monitor air quality is tiresome.
#
# </p>

# %% [markdown]
# <h4>9.	Assume this project was your idea, identify challenges in the project that can be future work as markdown. (2 marks)</h4>
# </h4>
# <p> it requires money and alot of time to think and develop the project</p>
# <p> heavy and too much information is  required to on daily, weekly and annually</p>
# <p> it requires many people to be invloved in the project completion </p>
